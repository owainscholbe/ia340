# %%
import pandas
import configparser
import psycopg2

# %%
config = configparser.ConfigParser()
config.read('config.ini')

host = config['myaws']['host']
db = config['myaws']['database']
user = config['myaws']['user']
pwd = config['myaws']['pwd']

# %%
conn = psycopg2.connect(host = host,
                       user = user,
                        password = pwd,
                        dbname = db
                       )
cur = conn.cursor()

# %%
table_sql = """
            CREATE TABLE IF NOT EXISTS indeed_gp12
            (
                id SERIAL,
                job_title VARCHAR(200),
                job_company VARCHAR(200),
                job_loc VARCHAR(200),
                job_salary VARCHAR(200),
                job_summary TEXT,
                PRIMARY KEY(id)
            );

            """

# %%
cur.execute(table_sql)
conn.commit()

# %%
url = 'https://www.indeed.com/jobs?q=intelligence+analyst&start=10'

# %%
import urllib.request
response = urllib.request.urlopen(url)
html_data= response.read()
#print(html_data.decode('utf-8'))

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data,'html.parser')
#print (soup)

# %%
for table_resultsBody in soup.find_all('table', id = 'resultsBody'):
    pass
    #print(table_resultsBody)

# %%
for table_pageContent in table_resultsBody.find_all('table', id = 'pageContent'):
    pass
    #print(table_pageContent)

# %%
for td_resultsCol in table_pageContent.find_all('td', id = 'resultsCol'):
    pass
    #print(td_resultsCol)

# %%
#  identify the job title, company, ratings, reviews, salary, and summary
for div_row in td_resultsCol.find_all('div', class_='jobsearch-SerpJobCard unifiedRow row result'):

    # find job title
    job_title = None
    job_company  = None
    job_rating = None
    job_loc = None
    job_salary = None
    job_summary = None
    for div_title in div_row.find_all('div', class_ = 'title'):
        job_title = div_title.text.strip().replace("'","_")
    
    for div_dsc in div_row.find_all('div', class_ = 'sjcl'):
        
        #find company name
        for span_company in div_dsc.find_all('span', class_ = 'company'):
            job_company = span_company.text.strip().replace("'","_")
        
        # find location
        for div_loc in div_dsc.find_all('div', class_ = 'location accessible-contrast-color-location'):
            job_loc = div_loc.text.strip().replace("'","_")
    
    # find salary
    for div_salary in div_row.find_all('div',class_ ='salarySnippet'):
        job_salary = div_salary.text.strip().replace("'","_")
    
    #find summary
    for div_summary in div_row.find_all('div', class_ = 'summary'):
        job_summary = div_summary.text.strip().replace("'","_")
        
    # insert into database
    
    sql_insert = """
                insert into indeed_gp12(job_title,job_company,job_loc,job_salary,job_summary)
                values('{}','{}','{}','{}','{}')            
                """.format(job_title,job_company,job_loc,job_salary,job_summary)

    cur.execute(sql_insert)
    conn.commit()

# %%
df = pandas.read_sql_query('select * from indeed_gp12', conn)
df[:]
# Out:
#     id                                          job_title  \
# 0    1                               Intelligence Analyst
# 1    2                   Quantitative Analyst / Developer
# 2    3  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 3    4                Training and Development Specialist
# 4    5           H-ISAC Cyber Threat Intelligence Analyst
# 5    6                                   Security Analyst
# 6    7                             Transportation Analyst
# 7    8                               Intelligence Analyst
# 8    9                       Intelligence Analyst I - MRS
# 9   10                               Intelligence Analyst
# 10  11                               Intelligence Analyst
# 11  12                               Intelligence Analyst
# 12  13  Global Intelligence & Travel Security Operatio...
# 13  14                               Intelligence Analyst
# 14  15                               Intelligence Analyst
# 15  16       Intelligence Analyst (Identity Intelligence)
# 16  17                               Intelligence Analyst
# 17  18  Undergraduate Internship/Co-op Program - Intel...
# 18  19               Associate Cyber Intelligence Analyst
# 19  20  Undergraduate Internship/Co-op Program - Intel...
# 20  21               Associate Cyber Intelligence Analyst
# 21  22                         Brand Intelligence Analyst
# 22  23                                   Security Analyst
# 23  24           H-ISAC Cyber Threat Intelligence Analyst
# 24  25                             Transportation Analyst
# 25  26                   Quantitative Analyst / Developer
# 26  27               Crisis Response Intelligence Analyst
# 27  28                               Intelligence Analyst
# 28  29         CIRT/Forensics/Threat Intelligence Analyst
# 29  30             Police Intelligence Analyst, Part-Time
# 30  31                   HIDTA Intelligence Analyst - ISC
# 31  32                               Intelligence Analyst
# 32  33           DEA Intelligence Analyst - DOMEX / Miami
# 33  34  Vulnerability Intelligence Analyst Internships...
# 34  35                Entry Level Threat Analyst ($15/hr)
# 35  36   Customer Experience Quality Assurance Specialist
# 36  37  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 37  38                               Intelligence Analyst
#
#                                         job_company  \
# 0                          National Security Agency
# 1                                         RT Signal
# 2                                           Maveris
# 3                                Marketresearch.com
# 4                                    Perch Security
# 5                                    Seen by Indeed
# 6                               Lipman Family Farms
# 7                               Booz Allen Hamilton
# 8                                        WorldAware
# 9                                       BAE Systems
# 10                            5 Stones intelligence
# 11                         National Security Agency
# 12                                        Pinkerton
# 13                           Red Five Security, LLC
# 14                                           Splunk
# 15                           Signature Science, LLC
# 16                              IntelliWare Systems
# 17                      Central Intelligence Agency
# 18                     LookingGlass Cyber Solutions
# 19                      Central Intelligence Agency
# 20                     LookingGlass Cyber Solutions
# 21                     LookingGlass Cyber Solutions
# 22                                   Seen by Indeed
# 23                                   Perch Security
# 24                              Lipman Family Farms
# 25                                        RT Signal
# 26                                        Pinkerton
# 27             Information Network Associates (INA)
# 28                                        Capgemini
# 29                          Allegheny County Police
# 30                          George Mason University
# 31                                     Itility, LCC
# 32  Solutions Through Innovative Technologies, Inc.
# 33                                    FireEye, Inc.
# 34                                       WMC Global
# 35             Virginia VA Information Technologies
# 36                                          Maveris
# 37                         National Security Agency
#
#                               job_loc                 job_salary  \
# 0                      Fort Meade, MD   $47,016 - $74,759 a year
# 1   New York, NY 10013 (Tribeca area)  $95,000 - $165,000 a year
# 2                     Martinsburg, WV   $60,000 - $70,000 a year
# 3                 Rockville, MD 20852                       None
# 4                      Titusville, FL   $50,000 - $75,000 a year
# 5                      Washington, DC                       None
# 6                 Immokalee, FL 34142                       None
# 7                                None                       None
# 8                                None                       None
# 9                                None                       None
# 10                               None                       None
# 11                               None   $47,016 - $74,759 a year
# 12                               None                       None
# 13                               None                       None
# 14                               None                       None
# 15                               None                       None
# 16                               None                       None
# 17                     Washington, DC    $21.21 - $22.43 an hour
# 18                   Reston, VA 20191                       None
# 19                     Washington, DC    $21.21 - $22.43 an hour
# 20                   Reston, VA 20191                       None
# 21                   Reston, VA 20191                       None
# 22                     Washington, DC                       None
# 23                     Titusville, FL   $50,000 - $75,000 a year
# 24                Immokalee, FL 34142                       None
# 25  New York, NY 10013 (Tribeca area)  $95,000 - $165,000 a year
# 26                               None                       None
# 27                               None                       None
# 28                               None                       None
# 29                               None             $1,907 a month
# 30                               None   $55,000 - $65,000 a year
# 31                               None                       None
# 32                               None                       None
# 33                               None                       None
# 34                               None                $15 an hour
# 35                               None   $66,798 - $90,000 a year
# 36                    Martinsburg, WV   $60,000 - $70,000 a year
# 37                     Fort Meade, MD   $47,016 - $74,759 a year
#
#                                           job_summary
# 0   The National Security Agency (NSA) is part of ...
# 1   We are a small, but well-funded (financially s...
# 2   The Analyst can identify risks in security sys...
# 3   _ The TACs are a subject matter expert for the...
# 4   Ability to communicate technical issues to tec...
# 5   Get matched – Companies apply to you with oppo...
# 6   Perform fact based, data driven analysis, and ...
# 7   We’re an EOE that empowers our people—no matte...
# 8   WorldAware is dedicated to equal opportunity i...
# 9   Having an understanding of physical and techni...
# 10  Analyze threat information from multiple sourc...
# 11  The National Security Agency (NSA) is part of ...
# 12  The Global Intelligence & Travel Security Oper...
# 13  We do not discriminate on the basis of race, r...
# 14  All qualified applicants will receive consider...
# 15  The purpose of this position is to provide tec...
# 16  The analyst will provide terrorist related thr...
# 17  Engineering, science students, or those in oth...
# 18  Past experience in intelligence, technology, c...
# 19  Engineering, science students, or those in oth...
# 20  Past experience in intelligence, technology, c...
# 21  The Brand Intelligence Analyst employs our pro...
# 22  Get matched – Companies apply to you with oppo...
# 23  Ability to communicate technical issues to tec...
# 24  Perform fact based, data driven analysis, and ...
# 25  We are a small, but well-funded (financially s...
# 26  The Crisis Response Intelligence Analyst, assi...
# 27  Environments, with a willingness to develop sp...
# 28  All qualified applicants will receive consider...
# 29  Please note that you MUST submit an applicatio...
# 30  HIIDTA Intelligence Analyst – ISC. The CEBCP c...
# 31  ITility strictly prohibits discrimination or h...
# 32  All qualified applicants will receive consider...
# 33  The team is not only responsible for performin...
# 34  Collaborate across teams to achieve company-wi...
# 35  Simultaneously, the specialist will begin work...
# 36  The Analyst can identify risks in security sys...
# 37  The National Security Agency (NSA) is part of ...
